# %% [markdown]
# # Программирование на Python
# ## Контрольная работа
# ### Практическая часть (10 баллов)

# %% [markdown]
# Фамилия, имя: <УКАЖИТЕ>

# %% [markdown]
# Активировать тесты:

# %%
# Фабрика тестов для проверки программ, принимающих данные через input()

from collections import deque

class Tester(object):
    def __init__(self, inp):
        self.outputs = []
        self.inputs = deque(inp)
    def print(self, *args, sep = " ", end = "\n"):
        text = sep.join(map(str, args)) + end
        newlines = text.splitlines(keepends=True)
        if self.outputs and self.outputs[-1] and self.outputs[-1][-1] != "\n" and newlines:
            self.outputs[-1] += newlines[0]
            self.outputs.extend(newlines[1:])
        else:
            self.outputs.extend(newlines)
            
    def input(self, *args):
        assert self.inputs, "Вы пытаетесь считать больше элементов, чем предусмотрено условием"
        return self.inputs.popleft()
    def __enter__(self):
        global print
        global input
        print = self.print
        input = self.input
        return self.outputs
    def __exit__(self, *args):
        global print
        global input
        del print
        del input

# %% [markdown]
# ### Задача 1 (2 балла)
#
# Реализуйте программу, которая фильтрует угощения из «Сладкого королевства» на основе их стоимости.
#
# * В переменную `items` считывается список, где хранятся названия сладостей (строки). Этот код уже написан.
# * В переменную `prices` считывается список, где хранятся цены сладостей (целые числа). Каждая цена соответствует товару из списка `items`. Этот код уже написан.
# * Гарантируется, что будет введена информация минимум для одного товара.
# * В переменную `req` считывается строка — минимальная и максимальная цена, которую ученики готовы заплатить за сладость (через пробел). Этот код уже написан.
# * Программа выводит названия сладостей, цены на которые не менее минимального введенного числа и не более максимального введенного числа.
#
# **Примеры работы программы:**
#
# Ввод:
#
#     шоколадная лягушка,перечный чертик
#     3,4
#     0 3
#
# Вывод:
#
#     шоколадная лягушка
#
#
# Ввод:
#
#     тараканьи грозди,берти ботс,шоколадный котелок,сахарное перо
#     8,6,4,3
#     4 7
#
# Вывод:
#
#     берти ботс
#     шоколадный котелок
#
# Ввод:
#
#     тыквенное печенье,сахарная мышка,берти ботс
#     3,3,6
#     1 2
#
# Вывод:
#
#     [ничего не выводится]

# %%
def problem01():
    
    items = input().split(",")
    prices = list(map(int, input().split(",")))
    req = input()
    
    ### BEGIN SOLUTION
    
    
    
    ### END SOLUTION
    
problem01()

# %%
test_data = [("шоколадная лягушка,перечный чертик;3,4;0 3",
              ["шоколадная лягушка"]),
             ("тараканьи грозди,берти ботс,шоколадный котелок,сахарное перо;8,6,4,3;4 7", 
              ["берти ботс", "шоколадный котелок"]),
             ("тыквенное печенье,сахарная мышка,берти ботс;3,3,6;1 2", []),
             ("кровяной леденец,мятный леденец,помадка;8,2,3;6 10", ["кровяной леденец"]),
             ("тараканьи грозди,берти ботс,шоколадный котелок,сахарное перо,шоколад;8,6,3,4,3;0 2", [])
             ]
for inp, out in test_data:
    with Tester(inp.split(";")) as t:
        problem01()
        line_t = "".join(t)
        t = line_t.splitlines()
        assert len(t) == len(out), "Неверный ответ"
        for l_test, l_out in zip(t, out):
            assert len(l_test.split()) == len(l_out.split()), "Неверный ответ"
            for el_test, el_out in zip(l_test.split(), l_out.split()):
                assert el_test == el_out, "Неверный ответ"

# %% [markdown]
# ### Задача 2 (2 балла)
#
# У профессора Снейпа на этой неделе очень плохое настроение, поэтому он
# не успокоится, пока в списке студентов, проваливших тест, не окажется Гарри Поттера.
# Ради этого он готов провести сколько угодно тестов.
#
# Реализуйте программу, которая считает количество тестов, написанных студентами.
#
# * Задан пустой список `who_failed`. Этот код уже написан.
# * В цикле считываются строки с перечнем фамилий студентов через пробел до тех пор, пока в перечне не окажется фамилии Potter. Гарантируется, что до строки с Potter будет введена как минимум одна строка с перечнем фамилий.
# * Каждую введенную фамилию добавляйте в список `who_failed`.
# * Напечатайте число написанных тестов.
#
# **Примеры работы программы:**
#
# Ввод:
#
#     Weasley Longbottom Bell
#     Crabbe Spinnet
#     Brown Potter
#
# Результат:
#
#     3
#
# Ввод:
#
#     Longbottom Bell
#     Crabbe Weasley Weasley
#     Spinnet Brown
#     Potter Weasley
#
# Результат:
#
#     4

# %%
def problem02():
    
    who_failed = []
    
    ### BEGIN SOLUTION
        
    
        
    ### END SOLUTION
    
problem02()

# %%
test_data = [("Longbottom Bell,Crabbe Weasley Weasley,Spinnet Brown,Potter Weasley",
              ["4"]),
             ("Weasley Longbottom Bell,Crabbe Spinnet,Brown Potter", ["3"]),
             ("A,B,C,D,E,Potter", ["6"])
             ]
for inp, out in test_data:
    with Tester(inp.split(",")) as t:
        problem02()
        line_t = "".join(t)
        t = line_t.splitlines()
        assert len(t) == len(out), "Неверный ответ"
        for l_test, l_out in zip(t, out):
            assert len(l_test.split()) == len(l_out.split()), "Неверный ответ"
            for el_test, el_out in zip(l_test.split(), l_out.split()):
                assert el_test == el_out, "Неверный ответ"

# %% [markdown]
# *Задача 3.1 и задача 3.2 – части одной большой задачи. Разбиение выполнено для того, чтобы за выполнение одной части можно было получить частичный балл. Задача 3.2 базируется на решении задачи 3.1.*

# %% [markdown]
# ### Задача 3.1 (2 балла)
#
# Реализуйте программу, которая позволяет сохранить данные по разным формам контроля по курсу трансфигурации.
#
# * В переменную `n` считывается число учеников (целое число). Гарантируется, что `n` не менее 2.
# * Далее `n` раз с клавиатуры запрашиваются четыре строки с данными в следующем формате (баллы – целые числа):
#
#         <Фамилия>
#         эссе <балл>
#         тест <балл>
#         практикум <балл>
#
# По результатам ввода формируется словарь `grades`. Ключами словаря `grades` являются фамилии студентов, значениями словаря – словари с их баллами по трем формам контроля. Гарантируется, что все вложенные словари состоят из одинакового числа элементов.
#
# Программа должна выводить на экран словарь `grades`.
#
#
# **Примеры работы программы:**
#
# Ввод:
#
#     3
#     Грейнджер
#     эссе 100
#     тест 98
#     практикум 100
#     Поттер
#     эссе 68
#     тест 70
#     практикум 82
#     Уизли
#     эссе 56
#     тест 60
#     практикум 44
#
# Вывод (для читаемости разбит на строки):
#
#     {'Грейнджер': {'эссе': 100, 'тест': 98, 'практикум': 100},
#     'Поттер': {'эссе': 68, 'тест': 70, 'практикум': 82},
#     'Уизли': {'эссе': 56, 'тест': 60, 'практикум': 44}}
#
#
# Ввод:
#
#     5
#     Грейнджер
#     эссе 100
#     тест 98
#     практикум 100
#     Поттер
#     эссе 68
#     тест 70
#     практикум 82
#     Уизли
#     эссе 56
#     тест 60
#     практикум 44
#     Браун
#     эссе 52
#     тест 48
#     практикум 56
#     Лавгуд
#     эссе 85
#     тест 72
#     практикум 92
#
# Вывод (для читаемости разбит на строки)::
#
#     {'Грейнджер' : {'эссе' : 100, 'тест' : 98, 'практикум' : 100},
#     'Поттер' : {'эссе' : 68, 'тест' : 70, 'практикум' : 82},
#         'Уизли' : {'эссе' : 56, 'тест' : 60, 'практикум' : 44},
#         'Браун' : {'эссе' : 52, 'тест' : 48, 'практикум' : 56},
#         'Лавгуд' : {'эссе' : 85, 'тест' : 72, 'практикум' : 92}}

# %%
def problem031():
    
    ### BEGIN SOLUTION
        
    
        
    ### END SOLUTION
    
problem031()
# Out:
# 5
# Грейнджер
# эссе 100
# тест 98
# практикум 100
# Поттер
# эссе 70
# тест 68
# практикум 82
# Уизли
# эссе 56
# тест 60
# практикум 44
# Браун
# эссе 52
# тест 48
# практикум 56
# Лавгуд
# эссе 85
# тест 72
# практикум 92
# {'Грейнджер': {'эссе': 100, 'тест': 98, 'практикум': 100}, 'Поттер': {'эссе': 70, 'тест': 68, 'практикум': 82}, 'Уизли': {'эссе': 56, 'тест': 60, 'практикум': 44}, 'Браун': {'эссе': 52, 'тест': 48, 'практикум': 56}, 'Лавгуд': {'эссе': 85, 'тест': 72, 'практикум': 92}}

# %%
test_data = [("3,Грейнджер,эссе 100,тест 98,практикум 100,Поттер,эссе 70,тест 68,практикум 82,Уизли,эссе 55,тест 60,практикум 44",
              ["{'Грейнджер': {'эссе': 100, 'тест': 98, 'практикум': 100}, 'Поттер': {'эссе': 70, 'тест': 68, 'практикум': 82}, 'Уизли': {'эссе': 55, 'тест': 60, 'практикум': 44}}"]),
             ("5,Грейнджер,эссе 100,тест 98,практикум 100,Поттер,эссе 70,тест 68,практикум 82,Уизли,эссе 56,тест 60,практикум 44,Браун,эссе 52,тест 48,практикум 56,Лавгуд,эссе 85,тест 72,практикум 92", 
              ["{'Грейнджер': {'эссе': 100, 'тест': 98, 'практикум': 100}, 'Поттер': {'эссе': 70, 'тест': 68, 'практикум': 82}, 'Уизли': {'эссе': 56, 'тест': 60, 'практикум': 44}, 'Браун': {'эссе': 52, 'тест': 48, 'практикум': 56}, 'Лавгуд': {'эссе': 85, 'тест': 72, 'практикум': 92}}"])]
for inp, out in test_data:
    with Tester(inp.split(",")) as t:
        problem031()
        line_t = "".join(t)
        t = line_t.splitlines()
        assert len(t) == len(out), "Неверный ответ"
        for l_test, l_out in zip(t, out):
            assert len(l_test.split()) == len(l_out.split()), "Неверный ответ"
            for el_test, el_out in zip(l_test.split(), l_out.split()):
                assert el_test == el_out, "Неверный ответ"

# %% [markdown]
# ### Задача 3.2 (4 балла)
#
# Реализуйте программу, которая позволяет определить, размах оценок за какую из двух выбранных форм контроля по курсу трансфигурации больше.
#
# * В переменную `n` считывается число учеников (целое число). Гарантируется, что `n` не менее 2.
# * Далее `n` раз с клавиатуры запрашиваются четыре строки с данными в следующем формате:
#
#         <Фамилия>
#         эссе <балл>
#         тест <балл>
#         практикум <балл>
#
# По результатам ввода формируется словарь `grades`. Ключами словаря `grades` являются фамилии студентов, значениями словаря – словари с их оценками по трем формам контроля. Гарантируется, что все вложенные словари состоят из одинакового числа элементов.
#
# * Далее в переменную `work1` считывается название одной формы контроля, а в переменную `work2` – название второй формы контроля.
#
# Программа должна выводить на экран словарь `grades` и через пробел строку с названием формы контроля, размах оценок за которую больше (размах вычисляется как разность между максимальным и минимальным значением).
#
#
# **Примеры работы программы:**
#
# Ввод:
#
#     3
#     Грейнджер
#     эссе 100
#     тест 98
#     практикум 100
#     Поттер
#     эссе 68
#     тест 70
#     практикум 82
#     Уизли
#     эссе 56
#     тест 60
#     практикум 44
#
#     эссе
#     тест
#
# Вывод:
#
#     {"Грейнджер" : {"эссе" : 100, "тест" : 98, "практикум" : 100},
#         "Поттер" : {"эссе" : 68, "тест" : 70, "практикум" : 82},
#         "Уизли" : {"эссе" : 56, "тест" : 60, "практикум" : 44}} эссе
#
#
# Ввод:
#
#     5
#     Грейнджер
#     эссе 100
#     тест 98
#     практикум 100
#     Поттер
#     эссе 68
#     тест 70
#     практикум 82
#     Уизли
#     эссе 56
#     тест 60
#     практикум 44
#     Браун
#     эссе 52
#     тест 48
#     практикум 56
#     Лавгуд
#     эссе 85
#     тест 72
#     практикум 92
#
#     практикум
#     тест
#
# Вывод:
#
#     {"Грейнджер" : {"эссе" : 100, "тест" : 98, "практикум" : 100},
#     "Поттер" : {"эссе" : 68, "тест" : 70, "практикум" : 82},
#         "Уизли" : {"эссе" : 56, "тест" : 60, "практикум" : 44},
#         "Браун" : {"эссе" : 52, "тест" : 48, "практикум" : 56},
#         "Лавгуд" : {"эссе" : 85, "тест" : 72, "практикум" : 92}} практикум

# %%
def problem032():
    
    ### BEGIN SOLUTION
        
    
        
    ### END SOLUTION
    
problem032()
# Out:
# 3
# Грейнджер
# эссе 100
# тест 98
# практикум 100
# Поттер
# эссе 68
# тест 70
# практикум 82
# Уизли
# эссе 56
# тест 60
# практикум 44
# эссе
# тест
# {'Грейнджер': {'эссе': 100, 'тест': 98, 'практикум': 100}, 'Поттер': {'эссе': 68, 'тест': 70, 'практикум': 82}, 'Уизли': {'эссе': 56, 'тест': 60, 'практикум': 44}} эссе

# %%
test_data = [("3,Грейнджер,эссе 100,тест 98,практикум 100,Поттер,эссе 70,тест 68,практикум 82,Уизли,эссе 55,тест 60,практикум 44,эссе,тест",
              ["{'Грейнджер': {'эссе': 100, 'тест': 98, 'практикум': 100}, 'Поттер': {'эссе': 70, 'тест': 68, 'практикум': 82}, 'Уизли': {'эссе': 55, 'тест': 60, 'практикум': 44}} эссе"]),
             ("5,Грейнджер,эссе 100,тест 98,практикум 100,Поттер,эссе 70,тест 68,практикум 82,Уизли,эссе 56,тест 60,практикум 44,Браун,эссе 52,тест 48,практикум 56,Лавгуд,эссе 85,тест 72,практикум 92,практикум,тест", 
              ["{'Грейнджер': {'эссе': 100, 'тест': 98, 'практикум': 100}, 'Поттер': {'эссе': 70, 'тест': 68, 'практикум': 82}, 'Уизли': {'эссе': 56, 'тест': 60, 'практикум': 44}, 'Браун': {'эссе': 52, 'тест': 48, 'практикум': 56}, 'Лавгуд': {'эссе': 85, 'тест': 72, 'практикум': 92}} практикум"])]
for inp, out in test_data:
    with Tester(inp.split(",")) as t:
        problem032()
        line_t = "".join(t)
        t = line_t.splitlines()
        assert len(t) == len(out), "Неверный ответ"
        for l_test, l_out in zip(t, out):
            assert len(l_test.split()) == len(l_out.split()), "Неверный ответ"
            for el_test, el_out in zip(l_test.split(), l_out.split()):
                assert el_test == el_out, "Неверный ответ"
