# %% [markdown]
# # Программирование на Python
#
# *Алла Тамбовцева*
#
# ## Практикум 6. Введение в парсинг с `BeautifulSoup`

# %% [markdown]
# Вы уже знакомы со структурой HTML-страниц и основными тэгами, теперь попробуем выгрузить информацию с сайта [nplus1.ru](https://nplus1.ru/). Наша задача – выгрузить недавние новости в датафрейм `pandas`, чтобы потом сохранить все в файл Excel.
#
# Для работы нам снова понадобится модуль `requests` для отправки запросов, для «подключения» к странице и получения ее содержимого в виде строки, и функция `BeautifulSoup` из библиотеки `bs4` для удобного поиска по полученной строке:

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Сохраним ссылку на главную страницу в переменную `main` и отправим запрос к ней с помощью функции `get()` из `requests`:

# %%
main = "https://nplus1.ru/"
page = requests.get(main)

# %%
page
# Out:
# <Response [200]>

# %% [markdown]
# Заберём исходный код страницы и преобразуем строку с ним в объект `BeautifulSoup`:

# %%
soup = BeautifulSoup(page.text)

# %% [markdown]
# Чтобы сгрузить все новости с главной страницы сайта, нужно собрать все ссылки на страницы с этими новостями. Ссылки в html-файле всегда заключены в тэг `<a></a>` и имеют атрибут `href`. Найдем кусочки кода HTML, соответствующие всем ссылкам на главной странице сайта:

# %%
links_raw = soup.find_all("a") 
links_raw[10:20]  # несколько штук для примера
# Out:
# [<a class="hover:underline transition-colors duration-75" href="/search/empty/768">Генетика</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/890">Математика</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/871">Космонавтика</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/876">Археология</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/775">Нейронауки</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/767">На мышах</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/771">Звук</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/772">Красота</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/778">Научные закрытия</a>,
#  <a class="hover:underline transition-colors duration-75" href="/search/empty/917">ИИ спешит на помощь</a>]

# %% [markdown]
# Каждый элемент возвращаемого списка имеет тип `BeautifulSoup` и структуру, очень похожую на словарь. Например, ссылка `<a class="hover:underline transition-colors duration-75" href="/search/empty/768">Генетика</a>` изнутри выглядит как словарь следующего вида:
#
#     {'href' : '/search/empty/768',
#      'class' : 'hover:underline transition-colors duration-75'}.
#
# Как мы помним, значение по ключу из словаря можно вызвать с помощью метода `.get()`. Давайте извлечем значения по ключу `href` из каждого элемента списка `links`:

# %%
links = [li.get("href") for li in links_raw] 
links[10:20]  # несколько штук для примера
# Out:
# ['/search/empty/768',
#  '/search/empty/890',
#  '/search/empty/871',
#  '/search/empty/876',
#  '/search/empty/775',
#  '/search/empty/767',
#  '/search/empty/771',
#  '/search/empty/772',
#  '/search/empty/778',
#  '/search/empty/917']

# %% [markdown]
# Ссылок в списке выше много. Но нам нужны только новости – ссылки, которые начинаются с `https://nplus1.ru/news`. Создадим пустой список `news` и будем добавлять в него только ссылки, которые удовлетворяют этому условию.

# %%
news = []
for li in links:
    if "https://nplus1.ru/news/" in li:
        news.append(li)

# %%
news[0:10]
# Out:
# ['https://nplus1.ru/news/2015/09/21/editor-thy-name',
#  'https://nplus1.ru/news/2023/05/19/octopus-nightmare',
#  'https://nplus1.ru/news/2023/05/19/permafrost',
#  'https://nplus1.ru/news/2023/05/19/ancient-hearth',
#  'https://nplus1.ru/news/2023/05/19/x-ray-forgery-update',
#  'https://nplus1.ru/news/2023/05/19/hoolock-tianxing',
#  'https://nplus1.ru/news/2023/05/19/sn-2020-eyj',
#  'https://nplus1.ru/news/2023/05/19/lp-791-18-d',
#  'https://nplus1.ru/news/2023/05/19/octopus-nightmare',
#  'https://nplus1.ru/news/2023/05/19/human-origins']

# %% [markdown]
# Первая ссылка ведет не совсем на новость, скорее, на объявление, поэтому давайте ее уберем:

# %%
news = news[1:]

# %% [markdown]
# Теперь наша задача сводится к следующему: изучить одну страницу с новостью, научиться из нее вытаскивать текст и всю необходимую информацию, а потом применить весь набор действий к каждой ссылке из `news` в цикле. Посмотрим на новость с индексом 0, у вас может быть другая, новости обновляются.

# %%
link0 = news[0]
print(link0)
# Out:
# https://nplus1.ru/news/2023/05/19/octopus-nightmare

# %% [markdown]
# ### Задача 1
#
# Отправьте запрос к странице по ссылке `link0` с одной новостью, получите результат в виде объекта `BeautifulSoup` и сохраните его как `soup0`.

# %%
page0 = requests.get(link0)
soup0 = BeautifulSoup(page0.text)

# %% [markdown]
# ### Задача 2
#
# Найдите заголовок новости и сохраните его в переменную `title`.

# %%
title = soup0.find("title").text

# %% [markdown]
# ### Задача 3
#
# Найдите имя автора новости и дату её публикации. Сохраните их в `author` и `date` соответственно.

# %%
date = soup0.find("meta", {"itemprop" : "datePublished"}).get("content") 
author = soup0.find("meta", {"name" : "author"}).get("content") 
print(date, author)
# Out:
# 2023-05-19 Сергей Коленов

# %% [markdown]
# ### Задача 4
#
# Найдите сложность новости и рубрики, к которым она относится. Сохраните сложность в переменную `diffc`. Рубрики сначала можно сохранить в список, а затем его элементы объединить в одну строку `rubs`.
#
# **Подсказка:** чтобы упростить себе жизнь, найдите сначала раздел (`div`), в котором на странице хранится дата и время публикации, сложность и рубрики, а затем выполняйте поиск в рамках этого раздела.

# %%
div = soup0.find("div", 
                 {"class" : "flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9"})
diffc = div.find_all("span")[3].text
rubs_raw = div.find_all("span")[4:] 
rubs_L = [r.text for r in rubs_raw] 
rubs = ", ".join(rubs_L)
print(rubs)
# Out:
# Зоология

# %% [markdown]
# ### Задача 5
#
# Соберите из абзацев текст новости и сохраните его в переменную `text`. Избавьтесь от постронних символов (`\xa0`, `\n`) в тексте.

# %%
pars_raw = soup0.find_all("p", {"class" : "mb-6"}) 
pars = [p.text for p in pars_raw] 
text = " ".join(pars)
text = text.replace("\xa0", " ").replace("\n", " ")
text
# Out:
# 'Во сне он вел себя так, словно на него напал хищник Зоологи заподозрили, что головоногие моллюски могут видеть кошмары. Понаблюдав за живущим в неволе осьминогом по имени Костелло, исследователи выявили четыре случая, когда он во сне резко менял цвет, беспорядочно двигал телом и конечностями и даже выпускал чернила. Возможно, спящий моллюск видел сновидения с участием хищников — и пытался от них защититься или сбежать. Препринт исследования опубликован на сайте bioRxiv.  Сновидения приходят к людям во время фазы быстрого сна, когда активность мозга повышена, мышцы расслаблены, а глаза совершают быстрые движения. Для многих позвоночных, головоногих моллюсков и даже пауков также описана фаза быстрого сна или ее аналоги. Зоологи допускают, что во время нее эти животные видят сны. Тем не менее, понять, что им снится, трудно. Лишь недавно исследователи научились расшифровывать простейшие детали мышиных сновидений по движениям их глаз. Однако есть одна группа животных, эмоции которых отражаются на поверхности их тела. Речь о головоногих моллюсках, которые меняют цвет в зависимости от настроения. Несколько лет назад зоологи обратили внимание, что окраска спящих осьминогов меняется в той же последовательности, что и во время бодрствования. Это навело их на мысль, что головоногие моллюски видят сны, в которых переживают события, происходившие с ними наяву. В пользу этой идеи также говорит то, что спящие осьминоги двигают конечностями. Команда зоологов под руководством Эрика Рамоса (Eric A. Ramos) из Рокфеллеровского университета описала необычный случай, который позволяет больше узнать о сновидениях головоногих моллюсков. Исследователи в течение нескольких месяцев наблюдали за поведением самца осьминога O. insularis по имени Костелло, которого поймали у берегов Флориды и держали в условиях лаборатории с февраля по апрель 2021 года (когда он умер от естественных причин). Движения моллюска круглосуточно записывали на три камеры. Проанализировав собранные материалы, исследователи выявили четыре эпизода, когда спящий Костелло резко менял цвет на темно-красный, беспорядочно двигал телом и конечностями, после чего переходил к поведению, характерному для осьминогов, которые спасаются от хищников или вступают в конфликты с сородичами, например, раздувал мантию, чтобы казаться больше. Три из них продолжались в среднем 44 секунды, а еще один — 769 секунд. В двух коротких эпизодах осьминог быстро возвращался в состояние покоя, а в еще одном коротком и одном длинном демонстрировал разнообразные движения. Например, во время длинного эпизода он сначала потемнел, потом сменил цвет на маскировочный пятнистый, а в конце даже выбросил облако чернил. Рамос и его соавторы предположили, что необычное поведение Костелло было связано с состоянием стресса. Возможно, он видел кошмары, в которых спасался от хищников или дрался с сородичами. Это особенно хорошо объясняет третий эпизод, который сильнее всего напоминает поведение людей, которые видят кошмары. Некоторые другие животные во сне тоже демонстрируют поведение, похожее на защитную или агрессивную реакции. Например, спящие домашние кошки (Felis catus) иногда выгибают спину, поднимают шерсть и передвигают ногами так, словно убегают.  Возможно, Костелло снились события из его жизни в дикой природе. Когда этого осьминога доставили в лабораторию, три его конечности были сильно повреждены, судя по всему, в результате встречи с хищником. Предыдущие исследования показали, что головоногие моллюски запоминают события, которые приводили к травмам или стрессу, поэтому Костелло тоже мог запомнить ситуацию, в которой лишился части конечностей — а затем воспроизводить ее во сне. Авторы не нашли никаких признаков того, что кошмары Костелло были вызваны какими-то внешними факторами. Некоторые такие эпизоды произошли, когда осьминог только осваивался в неволе и был перевозбужден. С другой стороны, необычное поведение моллюска могло быть связано с его старением. Рамос с коллегами подчеркивают, что объяснение, которое они  ...

# %% [markdown]
# ### Задача 6
#
# Напишите функцию `get_news()`, которая принимает на вход ссылку на страницу с одной новостью, а возвращает список из следующих характеристик: имя автора, дата публикации, сложность новости, рубрики, текст новости.
#
# *Да, мы пока не обсуждали написание функций в Python, но зато много раз сталкивались с ними в домашних заданиях.*

# %%
def get_news(link0):

    page0 = requests.get(link0)
    soup0 = BeautifulSoup(page0.text)
    title = soup0.find("title").text
    date = soup0.find("meta", {"itemprop" : "datePublished"}).get("content") 
    author = soup0.find("meta", {"name" : "author"}).get("content") 
    div = soup0.find("div", 
                 {"class" : "flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9"})
    diffc = div.find_all("span")[3].text
    rubs_raw = div.find_all("span")[4:] 
    rubs_L = [r.text for r in rubs_raw] 
    rubs = ", ".join(rubs_L)
    pars_raw = soup0.find_all("p", {"class" : "mb-6"}) 
    pars = [p.text for p in pars_raw] 
    text = " ".join(pars)
    text = text.replace("\xa0", " ").replace("\n", " ")
    
    return title, author, date, diffc, rubs, text

# %% [markdown]
# Отлично! Теперь осталось применить функцию ко всем ссылкам в списке `news`. Чтобы сайт не понял, что мы его автоматически грабим, будем выгружать новости постепенно – с задержкой в 1.5 секунды. Импортируем для этого функцию `sleep` :

# %%
from time import sleep

# %% [markdown]
# Теперь будем применять функцию в цикле к каждой ссылке в `news`, только с одним дополнением – добавленной конструкцией `try-except`, которая позволит продолжать исполнение цикла, если при применении функции Python столкнулся с ошибкой любого вида:

# %%
# уменьшили задержку до 1 секунды в sleep

info = []
for n in news:
    # пробуй исполнить следующий код
    try:
        res = get_news(n)
        info.append(res)
        print(n)
    # если он вызвал ошибку, печатай сообщение и иди дальше
    except:
        print("Something went wrong")
        print(n)
    sleep(1)
# Out:
# https://nplus1.ru/news/2023/05/19/octopus-nightmare
# https://nplus1.ru/news/2023/05/19/permafrost
# https://nplus1.ru/news/2023/05/19/ancient-hearth
# https://nplus1.ru/news/2023/05/19/x-ray-forgery-update
# https://nplus1.ru/news/2023/05/19/hoolock-tianxing
# https://nplus1.ru/news/2023/05/19/sn-2020-eyj
# https://nplus1.ru/news/2023/05/19/lp-791-18-d
# https://nplus1.ru/news/2023/05/19/octopus-nightmare
# https://nplus1.ru/news/2023/05/19/human-origins
# https://nplus1.ru/news/2023/05/19/dark-net-dark-bert
# https://nplus1.ru/news/2023/05/18/gorillas-adverse
# https://nplus1.ru/news/2023/05/18/rst-focal
# https://nplus1.ru/news/2023/05/18/tonsillectomy-in-adults
# https://nplus1.ru/news/2023/05/18/miliaria-crystallina
# https://nplus1.ru/news/2023/05/18/optimus-tesla-bot-updates
# https://nplus1.ru/news/2023/05/18/alisa-yandex-gpt
# https://nplus1.ru/news/2023/05/18/primary-diffuse-meningeal-melanomatosis
# https://nplus1.ru/news/2023/05/17/ufg-jwst
# https://nplus1.ru/news/2023/05/17/siler-collingwoodi
# https://nplus1.ru/news/2023/05/17/virgo-damaged-again
# https://nplus1.ru/news/2023/05/17/one-more-step-against-hiv
# https://nplus1.ru/news/2023/05/17/ethiopian-wolf
# https://nplus1.ru/news/2023/05/17/benzene-jwst
# https://nplus1.ru/news/2023/05/17/saturn-rings-young-or-not
# https://nplus1.ru/news/2023/05/17/ain-hanech
# https://nplus1.ru/news/2023/05/17/got-poison-get-remedy
# https://nplus1.ru/news/2023/05/17/extrasolar-radiation-belts
# https://nplus1.ru/news/2023/05/17/s-stars-lonely
# https://nplus1.ru/news/2023/05/16/talon-a-separation-test
# https://nplus1.ru/news/2023/05/16/238-p-read-jwst
# https://nplus1.ru/news/2023/05/16/at-2021-iwx
# https://nplus1.ru/news/2023/05/16/gluconeogenesis-covid
# https://nplus1.ru/news/2023/05/16/non-abelian-anyons
# https://nplus1.ru/news/2023/05/16/echospeech
# https://nplus1.ru/news/2023/05/16/butterflies-evolution
# https://nplus1.ru/news/2023/05/16/reln
# https://nplus1.ru/news/2023/05/16/you-are-cursed
# https://nplus1.ru/news/2023/05/16/roman-shipwreck
# https://nplus1.ru/news/2023/05/09/flint-dagger
# https://nplus1.ru/news/2023/04/25/elite-chariots
# https://nplus1.ru/news/2023/05/06/musth
# https://nplus1.ru/news/2020/06/01/gray-hair
# https://nplus1.ru/news/2023/05/08/china-cosmoplane-returns
# https://nplus1.ru/news/2023/05/09/neolithic-road
# https://nplus1.ru/news/2023/05/03/kosmos-2222-sgorel-v-atmosfere
# https://nplus1.ru/news/2023/05/19/human-origins
# https://nplus1.ru/news/2023/04/26/magdalenian-jet
# https://nplus1.ru/news/2023/05/05/uranus-oceans
# https://nplus1.ru/news/2023/05/16/you-are-cursed
# https://nplus1.ru/news/2023/05/15/fossil-footprints
# https://nplus1.ru/news/2023/04/27/puerto-rico
# https://nplus1.ru/news/2023/05/02/hetepheres
# https://nplus1.ru/news/2023/05/11/kosmoplan-subsputnik
# https://nplus1.ru/news/2023/04/27/balto
# https://nplus1.ru/news/2023/05/01/gamma-oscillations-in-the-dying-human-brain
# https://nplus1.ru/news/2023/05/17/ain-hanech
# https://nplus1.ru/news/2023/05/11/pangenome-is-here
# https://nplus1.ru/news/2023/05/01/muNe
# https://nplus1.ru/news/2023/05/02/710as
# https://nplus1.ru/news/2023/05/03/heating-into-a-solid
# https://nplus1.ru/news/2023/05/04/105-ions-crystal
# https://nplus1.ru/news/2023/05/04/straight-lines-for-champagne
# https://nplus1.ru/news/2023/05/06/seti-lte-mobile
# https://nplus1.ru/news/2023/05/11/pangenome-is-here
# https://nplus1.ru/news/2023/05/11/loophole-free-bell-inequality
# https://nplus1.ru/news/2023/05/13/no-hidden-bosons
# https://nplus1.ru/news/2023/05/13/talbot-carpet-helped
# https://nplus1.ru/news/2023/05/15/no-rtsc
# https://nplus1.ru/news/2023/05/16/non-abelian-anyons
# https://nplus1.ru/news/2023/05/16/at-2021-iwx
# https://nplus1.ru/news/2023/05/17/got-poison-get-remedy

# %% [markdown]
# Посмотрим на несколько элементов `info`:

# %%
info[10:12]
# Out:
# [('Детские травмы не\xa0снизили продолжительность жизни взрослых горилл',
#   'Катерина Петрова',
#   '2023-05-18',
#   '2.1',
#   'Зоология',
#   'Но увеличили риск смерти в раннем возрасте Гориллы, потерявшие в детстве родителя или пережившие рождение сиблинга, могут не дожить до шести лет. Но если доживут, то неблагоприятный детский опыт уже не сократит их жизнь, а в каких-то случаях даже увеличит ее продолжительность. Это выяснили исследователи из Великобритании, Руанды и США, которые уже более 50 лет наблюдают за гориллами в Национальном парке Вулканов. Исследование опубликовано в Current Biology. Негативный детский опыт обычно не очень хорошо влияет на жизнь уже взрослых людей: у них чаще возникают проблемы со здоровьем, а живут они хуже и меньше. Подобное происходит и со многими другими видами млекопитающих, особенно — с приматами [1, 2, 3]. Иногда последствия перенесенных в детстве травм могут догнать даже потомство. Но есть вид, у которого не совсем так, — это гориллы. Гориллы — наши довольно близкие родственники и живут они весьма долго — около 40 лет. При самых благоприятных условиях могут прожить и все 50. Можно было ожидать, что и события, которые мы называем детскими травмами, сказываются на них примерно так же, как и на нас. Ранее исследователи из Фонда горилл Дайан Фосси, которые более 50 лет наблюдают за популяцией горилл в Национальном парке Бирунга (Руанда), выяснили, что потеря матери в очень раннем возрасте — до 2,5 лет — наверняка приведет к смерти животного. Но если горилла потеряет мать в более позднем детстве, на ее выживаемость это не повлияет. Теперь ученые Фонда под руководством Робина Моррисона (Robin E. Morrison) изучили вопрос еще глубже. Они проанализировали данные уже 55-летних наблюдений за популяцией горилл, в которой было 135 самцов и 118 самок. В течении этого времени 85 животных умерли не достигнув возраста 6 лет, а еще 40 умерли уже будучи взрослыми. Исследователи выделили шесть неблагоприятных событий, с которыми гориллы могли столкнуться в детстве: потеря матери или отца (доминантного самца) до 6 лет, смерть ровесника (особи младше 6 лет) в результате убийства, групповая нестабильность — когда сменяется много членов группы, малое количество ровесников в группе (меньше двух), или рождение брата или сестры (до 3,5 лет). Появление сиблинга иногда считается неблагоприятным событием, потому что наличие брата или сестры может быть связано с большей конкуренцией — за ресурсы или родительские инвестиции. Выяснилось, что чем больше невзгод переживет горилла в раннем возрасте, тем скорее она умрет, не дожив до 6 лет. Так, два неблагоприятных события повышали риск смерти в 3,1 раза (p = 0,014), а три и более — уже в 26,6 раз (p < 0,001). Но если шестилетний рубеж горилла все-таки перешагнет, негативный детский опыт значимо не уменьшит продолжительность взрослой жизни. Выживаемость взрослых горилл несколько снижалась, если они потеряли мать до 3,3 лет (примерно в этом возрасте их обычно отлучают от груди), но не снижалась, если мать умирала позже. А вот потеря отца была опаснее, если происходила после 5,2 лет. В среднем же продолжительность жизни у горилл, переживших неблагоприятные события в детстве, не уменьшилась. А по отдельности потеря отца или появление сиблинга-конкурента даже снижали риск смерти. Коэффициент риска в первом случае был равен 0,126 (p = 0,011), а во втором — 0,342 (p = 0,038), тогда как обычный коэффициент — единица. Хотя между сиблингами может возникать конкуренция, наличие брата или сестры у примата может говорить о более здоровой матери, более быстром развитии потомства или большей поддержке группы — и, возможно, поэтому предсказывает большую продолжительность их жизни. Только групповая нестабильность оказалась связана с увеличением смертности в более позднем возрасте, да и только в том случае, если она перекрывалась с потерей отца. Это, отмечают авторы, стоит интерпретировать осторожно. Кроме того, пережитое не мешало животным достигать успехов. Один самец, Титус (1974–2009), потерял мать, отца и брата до того, как ему исполнилось 4 года. Тем не менее он вырос, стал лидером группы и сохранял свой статус еще двадцат ...
#  ('Телескоп «Роман» получил матрицу для основной камеры',
#   'Александр Войтюк',
#   '2023-05-18',
#   '1.9',
#   'Космонавтика',
#   'Он отправится в космос в 2027 году Американская компания Ball Aerospace изготовила матрицу фокальной плоскости, которая будет установлена в основном научном приборе космического телескопа «Роман» — 300-мегапиксельной камере WFI (Wide Field Instrument) с широким полем зрения. Матрица содержит 18 детекторов и будет охлаждаться при помощи радиаторов до рабочей температуры −178 градусов Цельсия, чтобы снизить уровень шума. Термовакуумные испытания WFI пройдут летом этого года, а весной 2024 года инструмент будет установлен на телескопе.   «Роман» станет новой крупной космической обсерваторией NASA и будет вести наблюдения в инфракрасном диапазоне. Обсерватория будет исследовать протопланетные диски и экзопланеты, темную материю и темную энергию, скопления галактик. В космос телескоп будет запущен в 2027 году при помощи ракеты-носителя Falcon Heavy. Ровер проехал вместе с камнем около 10 километров ')]

# %% [markdown]
# Финальный штрих – импортируем `pandas` и преобразуемый полученный список кортежей в датафрейм:

# %%
import pandas as pd

# %%
df = pd.DataFrame(info)
df.head()
# Out:
#                                                    0                1  \
# 0                       Осьминогу приснились кошмары   Сергей Коленов
# 1  В Салехарде открыли первую скважину сети монит...  Илья Ферапонтов
# 2  В Испании нашли очаги с сожженными примерно 24...  Михаил Подрезов
# 3  Кембриджский центр кристаллографических данных...      Михаил Бойм
# 4  Хулоки Скайуокера проснулись пораньше ради фру...   Сергей Коленов
#
#             2    3                  4  \
# 0  2023-05-19  1.7           Зоология
# 1  2023-05-19  1.3  Экология и климат
# 2  2023-05-19  3.3  Археология, Химия
# 3  2023-05-19  1.1              Химия
# 4  2023-05-19  1.7           Зоология
#
#                                                    5
# 0  Во сне он вел себя так, словно на него напал х...
# 1  Всего в сети будет 140 таких скважин Арктическ...
# 2  Это удалось выяснить, благодаря геохимическим ...
# 3  Расследование подлога данных продолжается Кемб...
# 4  Дело в том, что фруктовые деревья встречаются ...

# %% [markdown]
# Добавим содержательные названия столбцов и выгрузим датафрейм в файл:

# %%
df.columns = ["title", "author", "date", "diffc", "rubrics", "text"]

# %% [markdown]
# Дополнительно: давайте еще изменим тип столбца `diffc`, сделаем его `float` вместо `object` (`object` – аналог `string` в `pandas`).

# %%
df["diffc"] = df["diffc"].astype(float)

# %%
df.to_excel("nplus1.xlsx")
